# %% [markdown]
# #### Objective
#
# This notebook is to execute below tasks:
# 1. Fetch the data from GCS bucket
# 2. Filter key columns, required for Embeddings
# 3. Clean Columns and generate String Concating columns
# 4. Save output file back to GCS
# 5. Create another file with Diagnostic columns - to be used for recommendations and save to GCS

# %% [markdown]
# #### Python Version

# %%
from platform import python_version

print(python_version())

#ToDO - Need VM with python 3.10
# Out:
# 3.10.12

# %% [markdown]
# #### Install Libraries

# %%
# pip install ydata_profiling dtale

! pip install openai
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /root/anaconda3/include/python3.7m/UNKNOWN
# sysconfig: /root/anaconda3/include/python3.7m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Collecting openai
#   Downloading openai-1.6.1-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 1.6 MB/s eta 0:00:01
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 14.4 MB/s eta 0:00:01
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm>4 in /root/anaconda3/lib/python3.7/site-packages (from openai) (4.36.1)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 9.8 MB/s  eta 0:00:01
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.2 MB/s  eta 0:00:01
# Collecting typing-extensions<5,>=4.7
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: sniffio in /root/anaconda3/lib/python3.7/site-packages (from openai) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /root/anaconda3/lib/python3.7/site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 3.7 MB/s  eta 0:00:01
# Requirement already satisfied: certifi in /root/anaconda3/lib/python3.7/site-packages (from httpx<1,>=0.23.0->openai) (2021.10.8)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.9 MB/s  eta 0:00:01
# Collecting pydantic-core==2.14.6
#   Downloading pydantic_core-2.14.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 67.8 MB/s eta 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: importlib-metadata in /root/anaconda3/lib/python3.7/site-packages (from pydantic<3,>=1.9.0->openai) (0.23)
# Requirement already satisfied: zipp>=0.5 in /root/anaconda3/lib/python3.7/site-packages (from importlib-metadata->pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: more-itertools in /root/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata->pydantic<3,>=1.9.0->openai) (7.2.0)
# Installing collected packages: typing-extensions, exceptiongroup, h11, anyio, pydantic-core, httpcore, annotated-types, pydantic, httpx, distro, openai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.3.4
#     Uninstalling anyio-3.3.4:
#       Successfully uninstalled anyio-3.3.4
#   Attempting uninstall: distro
#     Found existing installation: distro 1.5.0
#     Uninstalling distro-1.5.0:
#       Successfully uninstalled distro-1.5.0
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /root/anaconda3/include/python3.7m/UNKNOWN
# sysconfig: /root/anaconda3/include/python3.7m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Successfully installed annotated-types-0.5.0 anyio-3.7.1 distro-1.9.0 exceptiongroup-1.2.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 openai-1.6.1 pydantic-2.5.3 pydantic-core-2.14.6 typing-extensions-4.7.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/root/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
# ! pip install tiktoken

# %%
# pip install google-cloud-aiplatform

# %% [markdown]
# #### Imports

# %%
# from utils.bq_utils import BQClient
import pandas as pd

# %% [markdown]
# #### Local python scripts path

# %%
import sys
sys.path.append("./keys")
sys.path.append("./utils")

# %% [markdown]
# #### Create BQ Client Object

# %%
# bq_client = BQClient()

# %% [markdown]
# #### Read Data From BQ and Store to Local

# %%
# # The ID of your GCS bucket
# bucket_name = "emopti_shared"

# # The ID of your GCS object
# source_blob_name = "aiipem_deidentified_data_1000_20231208.csv"
# # source_blob_name = "aiipem_deidentified_data_20231208.csv"
# # source_blob_name = "d2i_LOF_091123.txt"

# # The path to which the file should be downloaded
# destination_file_name = f"./data/{source_blob_name}"

# bq_client.download_blob(bucket_name, source_blob_name, destination_file_name)

# %% [markdown]
# #### Read data from Local and Filter required columns

# %%
print("Original DF: ")
df = pd.read_csv("./data/deidentified/aiipem_deidentified_data_20231208.csv")
display(df.head(2))

#### all columns
all_columns = df.columns.to_list()
        
id_column = ['PT_Visit_ID_Hashed']

columns_for_embeddings = ['Pt_Arrival_Method', 'Pt_Complaint', 'Pt_Triage_Acuity',
           'Pt_Gender', 'Pt_Race', 'Pt_Ethnicity', 'Pulse', 'Resp', 'SpO2', 'Temp', 
           'Arrival_TimeOfDay', 'Age_Group',
           'grouped_arrival_method', 'bp_group']

columns_for_output = ['EHR_Disposition', 'd2i_Grouped_Disposition', 'emopti_grouped_disposition']
columns_to_keep = id_column + columns_for_embeddings + columns_for_output
columns_dropped = list(set(all_columns) - set(columns_to_keep))

print(f"\n\nID Columns :{id_column}")
print(f"\nColumns For Embeddings :{columns_for_embeddings}")
print(f"\nColumns for output :{columns_for_output}")
print(f"\nColumns dropped :{columns_dropped}")
print(f"\nColumns to keep :{columns_to_keep}")

print("\n\nFiltered DF: ")

#### Save everything
# df = df[columns_to_keep]
display(df.head(2))
# Out:
# Original DF:
#                                   PT_Visit_ID_Hashed  \
# 0  c1cf913b612ffce254b33e996aa49b0def330b033058a7...
# 1  094a742f233f2699fe3125b34ee61421e3f5ae54e26ca2...
#
#                                         PT_ID_Hashed Pt_Arrival_Method  \
# 0  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...         Ambulance
# 1  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...               Car
#
#   Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race            Pt_Ethnicity  \
# 0   FLANK PAIN               3.0         F  UNKNOWN  Choose not to disclose
# 1    DIZZINESS               3.0         F  UNKNOWN  Choose not to disclose
#
#   Pt_Prime_ICD10 Pt_Secondary_ICD10  ...  Temp Visit_Duration_Hrs  \
# 0        O26.893              R10.2  ...  97.9                1.5
# 1          E86.0                D62  ...  97.9                4.5
#
#   Arrival_TimeOfDay Age_Group  Pt_DOB_Year  Systolic_BP  Diastolic_BP  \
# 0          12pm-6pm     20-40       1988.0        111.0          62.0
# 1      6pm-Midnight     20-40       1988.0        115.0          56.0
#
#     emopti_grouped_disposition  grouped_arrival_method bp_group
# 0  Left Against Medical Advice               ambulance   normal
# 1                   Discharged       private transport   normal
#
# [2 rows x 27 columns]
# ID Columns :['PT_Visit_ID_Hashed']
#
# Columns For Embeddings :['Pt_Arrival_Method', 'Pt_Complaint', 'Pt_Triage_Acuity', 'Pt_Gender', 'Pt_Race', 'Pt_Ethnicity', 'Pulse', 'Resp', 'SpO2', 'Temp', 'Arrival_TimeOfDay', 'Age_Group', 'grouped_arrival_method', 'bp_group']
#
# Columns for output :['EHR_Disposition', 'd2i_Grouped_Disposition', 'emopti_grouped_disposition']
#
# Columns dropped :['Pt_Prime_ICD10', 'Pt_Third_ICD10', 'PT_ID_Hashed', 'Diastolic_BP', 'Visit_Duration_Hrs', 'Pt_Secondary_ICD10', 'Systolic_BP', 'BP', 'Pt_DOB_Year']
#
# Columns to keep :['PT_Visit_ID_Hashed', 'Pt_Arrival_Method', 'Pt_Complaint', 'Pt_Triage_Acuity', 'Pt_Gender', 'Pt_Race', 'Pt_Ethnicity', 'Pulse', 'Resp', 'SpO2', 'Temp', 'Arrival_TimeOfDay', 'Age_Group', 'grouped_arrival_method', 'bp_group', 'EHR_Disposition', 'd2i_Grouped_Disposition', 'emopti_grouped_disposition']
#
#
# Filtered DF:
#                                   PT_Visit_ID_Hashed  \
# 0  c1cf913b612ffce254b33e996aa49b0def330b033058a7...
# 1  094a742f233f2699fe3125b34ee61421e3f5ae54e26ca2...
#
#                                         PT_ID_Hashed Pt_Arrival_Method  \
# 0  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...         Ambulance
# 1  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...               Car
#
#   Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race            Pt_Ethnicity  \
# 0   FLANK PAIN               3.0         F  UNKNOWN  Choose not to disclose
# 1    DIZZINESS               3.0         F  UNKNOWN  Choose not to disclose
#
#   Pt_Prime_ICD10 Pt_Secondary_ICD10  ...  Temp Visit_Duration_Hrs  \
# 0        O26.893              R10.2  ...  97.9                1.5
# 1          E86.0                D62  ...  97.9                4.5
#
#   Arrival_TimeOfDay Age_Group  Pt_DOB_Year  Systolic_BP  Diastolic_BP  \
# 0          12pm-6pm     20-40       1988.0        111.0          62.0
# 1      6pm-Midnight     20-40       1988.0        115.0          56.0
#
#     emopti_grouped_disposition  grouped_arrival_method bp_group
# 0  Left Against Medical Advice               ambulance   normal
# 1                   Discharged       private transport   normal
#
# [2 rows x 27 columns]

# %% [markdown]
# #### Clean and Prepare data for Embeddings

# %%
print("DF for Embeddings: ")
# df_for_embeddings = df[columns_for_embeddings].copy()
df_for_embeddings = df.copy()

display(df_for_embeddings.head(2))
# Out:
# DF for Embeddings:
#                                   PT_Visit_ID_Hashed  \
# 0  c1cf913b612ffce254b33e996aa49b0def330b033058a7...
# 1  094a742f233f2699fe3125b34ee61421e3f5ae54e26ca2...
#
#                                         PT_ID_Hashed Pt_Arrival_Method  \
# 0  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...         Ambulance
# 1  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...               Car
#
#   Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race            Pt_Ethnicity  \
# 0   FLANK PAIN               3.0         F  UNKNOWN  Choose not to disclose
# 1    DIZZINESS               3.0         F  UNKNOWN  Choose not to disclose
#
#   Pt_Prime_ICD10 Pt_Secondary_ICD10  ...  Temp Visit_Duration_Hrs  \
# 0        O26.893              R10.2  ...  97.9                1.5
# 1          E86.0                D62  ...  97.9                4.5
#
#   Arrival_TimeOfDay Age_Group  Pt_DOB_Year  Systolic_BP  Diastolic_BP  \
# 0          12pm-6pm     20-40       1988.0        111.0          62.0
# 1      6pm-Midnight     20-40       1988.0        115.0          56.0
#
#     emopti_grouped_disposition  grouped_arrival_method bp_group
# 0  Left Against Medical Advice               ambulance   normal
# 1                   Discharged       private transport   normal
#
# [2 rows x 27 columns]

# %% [markdown]
# #### EDA

# %%
df_for_embeddings['grouped_arrival_method'].value_counts()[0:20]
# Out:
# grouped_arrival_method
# private transport    419143
# ambulance             95477
# helicopter            14108
# police                 3831
# other                  2882
# Name: count, dtype: int64

# %%
# d = dtale.show(df_for_embeddings)
# print(d._main_url)

# %%
# ProfileReport(df_for_embeddings)

# %%
for col in df_for_embeddings.columns:
    print(f"\n\nColumn: {col}")
    print(f"\n{df_for_embeddings[col].value_counts()}")
# Out:
# Column: PT_Visit_ID_Hashed
#
# PT_Visit_ID_Hashed
# c1cf913b612ffce254b33e996aa49b0def330b033058a782cb0d7e5de368a121    1
# 69e4105bf4f0d1f749b69786ce57ed14cfcc988219445f26c67847ddb6bc9336    1
# 04c34b18b64d9ca80e53fb995e267f6112b342b2e4974e95a521ca1e44888be7    1
# 9a5d7f2f9d9700f0ac250343689ac95ba742ad9451076545ac76806ae8dac882    1
# ea0ff264f45c7d01f965f4a74939db774ffdf2ca47a412a1143da031d5666182    1
#                                                                    ..
# 8e11d91598d19a1b36107d043894d1c265bf983810fd0300cd4e9108bdedd98b    1
# 4a5b5d4661d2d0c0f79dc21a012ccfee2886a8ea787210b91a5312df336ebd27    1
# 4378143d798b52514a8588553bfc1c503caff5e2e16065a60ef998b1b1d07a36    1
# c73a1b9d2b13cc02a1699279b1c31921d21379a01e80d27c4b59e1aca129e831    1
# a84df23fbb604373367b4174e8c303717ce6868961fa17b94fadde1ceb4e76f7    1
# Name: count, Length: 531127, dtype: int64
#
#
# Column: PT_ID_Hashed
#
# PT_ID_Hashed
# 21a5eb45e5f94f4a2bec7f6179b1cee5187164281e26277b918131fe314fd282    172
# 22acd581d47e0b4f2be0255574d1f5e3604b3836e25b9da6ab77e93935ef1ba2    129
# 09365a26b5e03bbc4d5f1785e430887991bdad8835592ecb9fb870c5c0fa0d43    124
# 5c6506d021831d4fec587a501e73235577274294084ba2550c3b8bccce28138c    122
# 471d8fd7cfc05c7712f9fa8234ce65b715e40c1a43719fab29c400d27d5883db    115
#                                                                    ...
# 4ff47043aee7e97db99f1caa84f4c190587e6e743ae5cb0aab310dc91da06836      1
# 1a763fb01fda52561121d24286935663c545b0386302cc4139c68a0ec8789869      1
# d438708800422f502ab9255194efb0122fa6acd88c92ac15a16ab2ff7fa04678      1
# 5c26d4ccb0a1cdd9502fc52e7bcba6e256d6d22d5be8c9fd8848e640a33ee44b      1
# 20c4db231b32d03cd5c1b14ecac374f48229ccdc9d1e9e7f85642e861bfbee89      1
# Name: count, Length: 352641, dtype: int64
#
#
# Column: Pt_Arrival_Method
#
# Pt_Arrival_Method
# Car                               312736
# Walked In                          64619
# Ambulance                          45200
# Ambulatory                         14806
# Walk-In                            14660
#                                    ...
# Amb- Fountain Fire                     1
# Amb- Franktown Fire and Rescue         1
# Thornapple Twp Fire                    1
# Amb- South Platte Fire                 1
# Amb- Northglenn                        1
# Name: count, Length: 114, dtype: int64
#
#
# Column: Pt_Complaint
#
# Pt_Complaint
# ABDOMINAL PAIN         53152
# CHEST PAIN             29713
# SHORTNESS OF BREATH    21857
# FALL                   21650
# BACK PAIN              14551
#                        ...
# DAYTIME SLEEPINESS         1
# PTSD                       1
# DIAGNOSTIC TESTING         1
# BURN WOUND RETURN          1
# WEIGHT CHANGE              1
# Name: count, Length: 984, dtype: int64
#
#
# Column: Pt_Triage_Acuity
#
# Pt_Triage_Acuity
# 3.0    260964
# 4.0    136349
# 2.0    111657
# 5.0     14559
# 1.0      5356
# Name: count, dtype: int64
#
#
# Column: Pt_Gender
#
# Pt_Gender
# F    287884
# M    243122
# U        95
# X        15
# N        11
# Name: count, dtype: int64
#
#
# Column: Pt_Race
#
# Pt_Race
# UNKNOWN                                      408482
# WHITE OR CAUCASIAN                            89934
# BLACK OR AFRICAN AMERICAN                     22714
# NOT LISTED                                     3800
# SOMETHING ELSE                                 2193
# ASIAN                                          1011
# AMERICAN INDIAN OR ALASKA NATIVE                812
# OTHER (HISPANIC, LATINO/A)                      577
# CHOOSE NOT TO DISCLOSE                          500
# OTHER PACIFIC ISLANDER                          328
# OTHER                                           280
# UNABLE TO COLLECT                               216
# ARAB                                            200
# NATIVE HAWAIIAN                                  49
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER        23
# CHINESE                                           5
# FILIPINO                                          2
# JAPANESE                                          1
# Name: count, dtype: int64
#
#
# Column: Pt_Ethnicity
#
# Pt_Ethnicity
# Choose not to disclose                 516367
# American                                13743
# Other                                     393
# Mexican                                   232
# German                                     57
# Irish                                      37
# Dutch                                      32
# Arab                                       30
# English or British Isles                   29
# Amerindian                                 25
# Burmese                                    13
# Scottish                                   13
# Spaniard                                   12
# Italian                                    11
# Canadian                                   11
# Baltic Isles                               10
# Pole                                       10
# Guatemalan                                 10
# Jewish                                      8
# Southeast Asian                             7
# French                                      6
# Japanese                                    5
# Puerto Rican                                5
# Asian Indian                                5
# Filipino                                    5
# Chinese                                     5
# Chin                                        5
# Akan                                        4
# Yoruba                                      4
# Dominican                                   4
# Honduran                                    3
# Vietnamese                                  2
# Scandinavian                                2
# Swede                                       2
# Fulani                                      1
# Swahili                                     1
# Korean                                      1
# South Asian                                 1
# Afghan                                      1
# Norwegian                                   1
# Samoan                                      1
# Kayah                                       1
# West Asian                                  1
# Ecuadorian                                  1
# Oromo                                       1
# North Asian                                 1
# East Asian                                  1
# Middle Eastern North African (MENA)         1
# Shona                                       1
# Greek                                       1
# Cuban                                       1
# Salvadoran                                  1
# Finnish                                     1
# Kongo                                       1
# Name: count, dtype: int64
#
#
# Column: Pt_Prime_ICD10
#
# Pt_Prime_ICD10
# R07.89      11816
# R07.9        9376
# J06.9        9056
# R11.2        8798
# S09.90XA     5901
#             ...
# S32.512G        1
# T82.528A        1
# G47.411         1
# A07.0           1
# O26.41          1
# Name: count, Length: 10400, dtype: int64
#
#
# Column: Pt_Secondary_ICD10
#
# Pt_Secondary_ICD10
# R11.2       4376
# R07.89      3497
# R19.7       2603
# F17.210     2419
# R10.84      1888
#             ...
# M24.421        1
# M21.331        1
# T23.131A       1
# S32.122A       1
# H04.121        1
# Name: count, Length: 6540, dtype: int64
#
#
# Column: Pt_Third_ICD10
#
# Pt_Third_ICD10
# Y92.89      5399
# Z20.822     2611
# F17.210     2318
# R11.2       1623
# Z87.891     1318
#             ...
# T42.6X4A       1
# L03.126        1
# G56.03         1
# I74.8          1
# M01.X62        1
# Name: count, Length: 4231, dtype: int64
#
#
# Column: EHR_Disposition
#
# EHR_Disposition
# Discharge                                                418029
# Hospitalized                                              31986
# IP Bed Requested                                          17954
# Admit                                                     16543
# Transfer to Another Facility                              11454
#                                                           ...
# Hospice/Home (HH)                                             1
# Short Term Acute Care Hospital w/ Planned Readmission         1
# Home-Health Care Svc (HHA)                                    1
# Home or Self Care w/ Planned Readmission                      1
# Discharge to GIP Hospice                                      1
# Name: count, Length: 63, dtype: int64
#
#
# Column: d2i_Grouped_Disposition
#
# d2i_Grouped_Disposition
# Discharged     419033
# Admitted        68661
# Transferred     12053
# Admit Obs       10504
# LWBS            10398
# Transfer         5500
# AMA              2334
# Eloped           1993
# Not Defined       420
# Expired           231
# Name: count, dtype: int64
#
#
# Column: BP
#
# BP
# 130/80     525
# 120/80     407
# 140/90     386
# 140/80     379
# 128/78     375
#           ...
# 290/140      1
# 263/137      1
# 149/37       1
# 179/41       1
# 223/139      1
# Name: count, Length: 14606, dtype: int64
#
#
# Column: Pulse
#
# Pulse
# 80.0     13238
# 88.0     11950
# 78.0     11558
# 85.0     11405
# 90.0     11338
#          ...
# 236.0        1
# 257.0        1
# 245.0        1
# 240.0        1
# 4.0          1
# Name: count, Length: 250, dtype: int64
#
#
# Column: Resp
#
# Resp
# 18.0     170743
# 16.0     121304
# 20.0      82671
# 22.0      26384
# 17.0      20429
#           ...
# 144.0         1
# 125.0         1
# 90.0          1
# 79.0          1
# 107.0         1
# Name: count, Length: 129, dtype: int64
#
#
# Column: SpO2
#
# SpO2
# 100.0    133440
# 98.0      96995
# 99.0      85218
# 97.0      73224
# 96.0      51740
#           ...
# 6.0           1
# 27.0          1
# 28.0          1
# 3.0           1
# 32.0          1
# Name: count, Length: 88, dtype: int64
#
#
# Column: Temp
#
# Temp
# 98.2     50083
# 98.1     49883
# 97.9     41760
# 98.4     40146
# 97.7     34456
#          ...
# 85.4         1
# 107.5        1
# 86.2         1
# 82.4         1
# 87.9         1
# Name: count, Length: 228, dtype: int64
#
#
# Column: Visit_Duration_Hrs
#
# Visit_Duration_Hrs
# 2.0      62422
# 1.5      55386
# 2.5      54637
# 3.0      52167
# 1.0      50278
#          ...
# 80.0         1
# 64.0         1
# 153.5        1
# 98.5         1
# 133.0        1
# Name: count, Length: 206, dtype: int64
#
#
# Column: Arrival_TimeOfDay
#
# Arrival_TimeOfDay
# 12pm-6pm        190981
# 6pm-Midnight    152903
# 6am-12pm        134829
# Midnight-6am     52414
# Name: count, dtype: int64
#
#
# Column: Age_Group
#
# Age_Group
# 20-40     146695
# 40-60     115300
# 60-80     113768
# 2-13       53830
# 80-100     42439
# 13-20      38162
# 1-2         9656
# 0-.5        5702
# .5-1        5575
# Name: count, dtype: int64
#
#
# Column: Pt_DOB_Year
#
# Pt_DOB_Year
# 2022.0    10929
# 2021.0     8644
# 2001.0     7987
# 1991.0     7943
# 1990.0     7818
#           ...
# 1927.0      589
# 1926.0      429
# 1925.0      378
# 1924.0      212
# 1923.0      112
# Name: count, Length: 101, dtype: int64
#
#
# Column: Systolic_BP
#
# Systolic_BP
# 130.0    9080
# 132.0    8896
# 128.0    8641
# 126.0    8566
# 129.0    8562
#          ...
# 34.0        1
# 35.0        1
# 465.0       1
# 41.0        1
# 33.0        1
# Name: count, Length: 239, dtype: int64
#
#
# Column: Diastolic_BP
#
# Diastolic_BP
# 80.0     13802
# 78.0     13542
# 76.0     12696
# 82.0     12618
# 79.0     12575
#          ...
# 213.0        1
# 234.0        1
# 12.0         1
# 221.0        1
# 219.0        1
# Name: count, Length: 208, dtype: int64
#
#
# Column: emopti_grouped_disposition
#
# emopti_grouped_disposition
# Discharged                     419033
# Not Discharged                  96718
# Left Without Being Seen         10398
# Left Against Medical Advice      4327
# Not Defined                       420
# Expired                           231
# Name: count, dtype: int64
#
#
# Column: grouped_arrival_method
#
# grouped_arrival_method
# private transport    416216
# ambulance             94494
# helicopter            13939
# police                 3804
# other                  2674
# Name: count, dtype: int64
#
#
# Column: bp_group
#
# bp_group
# high       208033
# at_risk    166629
# normal     116536
# 0           32977
# low          6952
# Name: count, dtype: int64
#
#
# Column: combined
#
# combined
# Complaint: ABDOMINAL PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 100.0; Resp: 18.0; SpO2: 100.0; Temp: 98.2; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high    4
# Complaint: ABDOMINAL PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 94.0; Resp: 16.0; SpO2: 100.0; Temp: 98.2; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: at_risk      3
# Complaint: ABDOMINAL PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 91.0; Resp: 16.0; SpO2: 100.0; Temp: 98.2; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high     3
# Complaint: ABDOMINAL PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 70.0; Resp: 18.0; SpO2: 100.0; Temp: 98.1; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal       3
# Complaint: ABDOMINAL PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 85.0; Resp: 18.0; SpO2: 98.0; Temp: 97.9; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: high      3
#                                                                                                                                                                                                                                                                               ..
# Complaint: KNEE INJURY; Triage_Acuity: 4.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 70.0; Resp: 18.0; SpO2: 99.0; Temp: 98.1; Arrival_TimeOfDay: 6am-12pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal           1
# Complaint: ARM INJURY; Triage_Acuity: 4.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 92.0; Resp: 18.0; SpO2: 98.0; Temp: 98.2; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: at_risk           1
# Complaint: BACK PAIN; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 91.0; Resp: 20.0; SpO2: 100.0; Temp: 98.8; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: high          1
# Complaint: VAGINAL BLEEDING; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 98.0; Resp: 18.0; SpO2: 98.0; Temp: 98.1; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high        1
# Complaint: EDEMA; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 88.0; Resp: 18.0; SpO2: 96.0; Temp: 97.6; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 80-100; Grouped_Arrival_Method: private transport; BP_Group: at_risk    1
# Name: count, Length: 530130, dtype: int64

# %% [markdown]
# #### Include 'Diastolic_BP' and 'Systolic_BP', "Arrival Method' (could be tried)

# %% [markdown]
# #### Concate Columns

# %%
df_for_embeddings.columns
# Out:
# Index(['PT_Visit_ID_Hashed', 'PT_ID_Hashed', 'Pt_Arrival_Method',
#        'Pt_Complaint', 'Pt_Triage_Acuity', 'Pt_Gender', 'Pt_Race',
#        'Pt_Ethnicity', 'Pt_Prime_ICD10', 'Pt_Secondary_ICD10',
#        'Pt_Third_ICD10', 'EHR_Disposition', 'd2i_Grouped_Disposition', 'BP',
#        'Pulse', 'Resp', 'SpO2', 'Temp', 'Visit_Duration_Hrs',
#        'Arrival_TimeOfDay', 'Age_Group', 'Pt_DOB_Year', 'Systolic_BP',
#        'Diastolic_BP', 'emopti_grouped_disposition', 'grouped_arrival_method',
#        'bp_group', 'combined'],
#       dtype='object')

# %%
df_for_embeddings["combined"] = ("Complaint: " + df_for_embeddings['Pt_Complaint'].str.strip() + 
                #   "; Arrival_Method: " + df_for_embeddings['Pt_Arrival_Method'].str.strip() + 
                  "; Triage_Acuity: " + df_for_embeddings['Pt_Triage_Acuity'].astype(str).str.strip() + 
                  "; Gender: " + df_for_embeddings['Pt_Gender'].str.strip() + 
                  "; Race: " + df_for_embeddings['Pt_Race'].str.strip() + 
                  "; Ethnicity: " + df_for_embeddings['Pt_Ethnicity'].str.strip() + 
                  "; Pulse: " + df_for_embeddings['Pulse'].astype(str).str.strip() + 
                  "; Resp: " + df_for_embeddings['Resp'].astype(str).str.strip() + 
                  "; SpO2: " + df_for_embeddings['SpO2'].astype(str).str.strip() + 
                  "; Temp: " + df_for_embeddings['Temp'].astype(str).str.strip() + 
                  "; Arrival_TimeOfDay: " + df_for_embeddings['Arrival_TimeOfDay'].str.strip() + 
                  "; Age_Group: " + df_for_embeddings['Age_Group'].str.strip() + 
                  "; Grouped_Arrival_Method: " + df_for_embeddings['grouped_arrival_method'].str.strip() + 
                  "; BP_Group: " + df_for_embeddings['bp_group'].str.strip()
                  )
display(df_for_embeddings.head(2))
# Out:
#                                   PT_Visit_ID_Hashed  \
# 0  c1cf913b612ffce254b33e996aa49b0def330b033058a7...
# 1  094a742f233f2699fe3125b34ee61421e3f5ae54e26ca2...
#
#                                         PT_ID_Hashed Pt_Arrival_Method  \
# 0  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...         Ambulance
# 1  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...               Car
#
#   Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race            Pt_Ethnicity  \
# 0   FLANK PAIN               3.0         F  UNKNOWN  Choose not to disclose
# 1    DIZZINESS               3.0         F  UNKNOWN  Choose not to disclose
#
#   Pt_Prime_ICD10 Pt_Secondary_ICD10  ... Visit_Duration_Hrs Arrival_TimeOfDay  \
# 0        O26.893              R10.2  ...                1.5          12pm-6pm
# 1          E86.0                D62  ...                4.5      6pm-Midnight
#
#   Age_Group Pt_DOB_Year  Systolic_BP  Diastolic_BP  \
# 0     20-40      1988.0        111.0          62.0
# 1     20-40      1988.0        115.0          56.0
#
#     emopti_grouped_disposition  grouped_arrival_method  bp_group  \
# 0  Left Against Medical Advice               ambulance    normal
# 1                   Discharged       private transport    normal
#
#                                             combined
# 0  Complaint: FLANK PAIN; Triage_Acuity: 3.0; Gen...
# 1  Complaint: DIZZINESS; Triage_Acuity: 3.0; Gend...
#
# [2 rows x 28 columns]

# %%
print(f"Sample Patient info: \n{df_for_embeddings['combined'].iloc[0]}")
# Out:
# Sample Patient info:
# Complaint: FLANK PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 90.0; Resp: 20.0; SpO2: 99.0; Temp: 97.9; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: ambulance; BP_Group: normal

# %%
print(f"DF shape before drop_NA: {df_for_embeddings.shape}")

df_for_embeddings.dropna(subset = ['combined'], inplace=True)
print(f"DF shape after drop_NA: {df_for_embeddings.shape}")
# Out:
# DF shape before drop_NA: (535441, 28)
# DF shape after drop_NA: (531127, 28)

# %% [markdown]
# #### Embeddings Model

# %%
# imports
from keys import OPENAI_KEY
from embeddings_utils import get_embedding, cosine_similarity, get_embeddings

# from keys.keys import OPENAI_KEY
# from utils.embeddings_utils import get_embedding, cosine_similarity, get_embeddings

import openai
# Set up your API credentials
openai.api_key = OPENAI_KEY

# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %% [markdown]
# #### Approximate Tokens and Cost calculation

# %%
# import tiktoken

# encoding = tiktoken.get_encoding(embedding_encoding)
# n_tokens_list = []

# # omit reviews that are too long to embed
# df_for_embeddings["n_tokens"] = df_for_embeddings.combined.apply(lambda x: len(encoding.encode(x)))

# print(f"df len: {len(df_for_embeddings)}")
# display(df_for_embeddings.head(2))

# print(f"# Tokens: {df_for_embeddings['n_tokens'].sum()}")

# %%
# #### Cost
# n_tokens = df_for_embeddings['n_tokens'].sum()
# per_1k_price = 0.0001 
# print(f"approximate cost: ${round(n_tokens * per_1k_price/1000, 2)}")

# #### Cost for 100k comments
# n_tokens = df_for_embeddings[0:100000]['n_tokens'].sum()
# per_1k_price = 0.0001 
# print(f"approximate cost: ${round(n_tokens * per_1k_price/1000, 2)}")

# %%
# df_for_embeddings.to_csv("./data/deidentified/aiipem_deidentified_before_embeddings.csv.gz", index= False, compression='gzip')
# df_for_embeddings.head(2)

# %% [markdown]
# #### Generate Embeddings

# %%
#### Time taken in sequential order for 10k patients --> 50 seconds
import time

# Ensure you have your API key set in your environment per the README: https://github.com/openai/openai-python#usage
start_time= time.time()
df_copy = df_for_embeddings[0:10000].copy()
embedding_list = []
batch_size = 2048

for idx in range(0, len(df_copy)-1, batch_size):
    start_idx = idx
    end_idx = min(10000, idx+batch_size)
    print(f"embeddings for: {start_idx, end_idx}")
    txt_list = df_copy['combined'].iloc[start_idx:end_idx]
    embedding_values = get_embeddings(txt_list, model=embedding_model)
    embedding_list.extend(embedding_values)

print(f"time taken for embeddings : {time.time()- start_time}")

df_copy["embedding"]  = embedding_list

print(f"\nsaving embedings to disk:")
print(f"embedings df shape: {df_copy.shape}")

start_time= time.time()
df_copy.to_csv("./data/deidentified/aiipem_deidentified_embeddings_batch_0_to_10k.csv.gz", index= False, compression='gzip')
print(f"time taken to save embeddings: {time.time()- start_time}")
# Out:
# embeddings for: (0, 2048)
# embeddings for: (2048, 4096)
# embeddings for: (4096, 6144)
# embeddings for: (6144, 8192)
# embeddings for: (8192, 10000)
# time taken for embeddings : 132.93656754493713
# saving embedings to disk:
# embedings df shape: (10000, 29)

# %%
display(df_copy.head(2))
df_copy.shape
# Out:
#                                   PT_Visit_ID_Hashed  \
# 0  c1cf913b612ffce254b33e996aa49b0def330b033058a7...
# 1  094a742f233f2699fe3125b34ee61421e3f5ae54e26ca2...
#
#                                         PT_ID_Hashed Pt_Arrival_Method  \
# 0  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...         Ambulance
# 1  e1866701283c7c46f57bff8b5d23c1d44fbbfca0a076a1...               Car
#
#   Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race            Pt_Ethnicity  \
# 0   FLANK PAIN               3.0         F  UNKNOWN  Choose not to disclose
# 1    DIZZINESS               3.0         F  UNKNOWN  Choose not to disclose
#
#   Pt_Prime_ICD10 Pt_Secondary_ICD10  ... Arrival_TimeOfDay Age_Group  \
# 0        O26.893              R10.2  ...          12pm-6pm     20-40
# 1          E86.0                D62  ...      6pm-Midnight     20-40
#
#   Pt_DOB_Year Systolic_BP  Diastolic_BP   emopti_grouped_disposition  \
# 0      1988.0       111.0          62.0  Left Against Medical Advice
# 1      1988.0       115.0          56.0                   Discharged
#
#    grouped_arrival_method  bp_group  \
# 0               ambulance    normal
# 1       private transport    normal
#
#                                             combined  \
# 0  Complaint: FLANK PAIN; Triage_Acuity: 3.0; Gen...
# 1  Complaint: DIZZINESS; Triage_Acuity: 3.0; Gend...
#
#                                            embedding
# 0  [0.009560050442814827, 0.002757575362920761, 0...
# 1  [0.011276663281023502, 0.003159793559461832, 0...
#
# [2 rows x 29 columns]
# (10000, 29)

# %% [markdown]
# #### Read Embeddings from Disk

# %%
import pandas as pd
import time
import numpy as np
from ast import literal_eval

datafile_path = "./data/deidentified/aiipem_deidentified_embeddings_batch_0_to_10k.csv.gz"

start_time= time.time()
df_copy = pd.read_csv(datafile_path)
print(f"time takento read csv: {time.time()- start_time}")

start_time= time.time()
df_copy["embedding"] = df_copy.embedding.apply(literal_eval).apply(np.array)
print(f"time taken for literal_eval: {time.time()- start_time}")

display(df_copy.head(2))
df_copy.shape
# Out:
# time takento read csv: 13.978440284729004
# time taken for literal_eval: 73.75912046432495
#   Pt_Arrival_Method Pt_Complaint  Pt_Triage_Acuity Pt_Gender  Pt_Race  \
# 0         Ambulance   FLANK PAIN               3.0         F  UNKNOWN
# 1               Car    DIZZINESS               3.0         F  UNKNOWN
#
#              Pt_Ethnicity  Pulse  Resp   SpO2  Temp Arrival_TimeOfDay  \
# 0  Choose not to disclose   90.0  20.0   99.0  97.9          12pm-6pm
# 1  Choose not to disclose  104.0  18.0  100.0  97.9      6pm-Midnight
#
#   Age_Group grouped_arrival_method bp_group  \
# 0     20-40              ambulance   normal
# 1     20-40      private transport   normal
#
#                                             combined  n_tokens  \
# 0  Complaint: FLANK PAIN; Triage_Acuity: 3.0; Gen...        97
# 1  Complaint: DIZZINESS; Triage_Acuity: 3.0; Gend...        98
#
#                                            embedding
# 0  [0.009560050442814827, 0.002757575362920761, 0...
# 1  [0.011276663281023502, 0.003159793559461832, 0...
# (10000, 17)

# %% [markdown]
# #### Cosine Similarity

# %%
from utils.embeddings_utils import get_embedding, cosine_similarity

# search through the patients for a specific patient
def search_patients(df, patient_info):
    product_embedding = get_embedding(patient_info, model=embedding_model)
    df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, product_embedding))

    results = df.sort_values("similarity", ascending=False)
    return results

bold_s = "\033[1m"
bold_e = "\033[0m"

# %%
# 'Pt_Prime_ICD10' 'Pt_Secondary_ICD10', 'Pt_Third_ICD10'
# 'EHR_Disposition', 'd2i_Grouped_Disposition', 'emopti_grouped_disposition'

# %% [markdown]
# #### Example 1

# %%
top_k = 5
patient_id = 10005
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
results = search_patients(df_patient_search, patient_info['combined'])

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 108.0; Resp: 28.0; SpO2: 100.0; Temp: 98.4; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 2-13; Grouped_Arrival_Method: private transport; BP_Group: normal
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 139.0; Resp: 35.0; SpO2: 97.0; Temp: 99.3; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 2-13; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9992981698019001
# Pt_Prime_ICD10: K29.70
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 99.0; Resp: 16.0; SpO2: 98.0; Temp: 99.6; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9983104811427408
# Pt_Prime_ICD10: K52.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 71.0; Resp: 16.0; SpO2: 98.0; Temp: 98.0; Arrival_TimeOfDay: 6am-12pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.998211419963467
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 132.0; Resp: 24.0; SpO2: 100.0; Temp: 98.2; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 2-13; Grouped_Arrival_Method: private transport; BP_Group: 0
# Similariry: 0.9982040414205944
# Pt_Prime_ICD10: R11.10
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 95.0; Resp: 18.0; SpO2: 97.0; Temp: 98.5; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9980682999458446
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan

# %% [markdown]
# #### Example 2

# %%
df_patient_search = df_copy.copy()

patient_info = "Complaint: EMESIS"
results = search_patients(df_patient_search, patient_info)

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info}")
print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: EMESIS
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: Other; Pulse: 81.0; Resp: 24.0; SpO2: 100.0; Temp: 98.0; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 60-80; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.874676077908779
# Pt_Prime_ICD10: K43.6
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: American; Pulse: 75.0; Resp: 16.0; SpO2: 100.0; Temp: 98.3; Arrival_TimeOfDay: 6am-12pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.8742737063931766
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 57.0; Resp: 16.0; SpO2: 99.0; Temp: 97.8; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: at_risk
# Similariry: 0.8729706850506187
# Pt_Prime_ICD10: R11.10
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 69.0; Resp: 15.0; SpO2: 98.0; Temp: 97.4; Arrival_TimeOfDay: Midnight-6am; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.8729492072166393
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: EMESIS; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: American; Pulse: 82.0; Resp: 18.0; SpO2: 100.0; Temp: 98.0; Arrival_TimeOfDay: Midnight-6am; Age_Group: 60-80; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.8728409585040044
# Pt_Prime_ICD10: N20.1
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan

# %% [markdown]
# #### Example 3

# %%
df_patient_search = df_copy.copy()

patient_info = "Complaint: EMESIS; Pulse: 130.0"
results = search_patients(df_patient_search, patient_info)

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info}")
print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: EMESIS; Pulse: 130.0
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: M; Race: SOMETHING ELSE; Ethnicity: Other; Pulse: 75.0; Resp: 18.0; SpO2: 100.0; Temp: 98.2; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 13-20; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9021883769831781
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: American; Pulse: 75.0; Resp: 16.0; SpO2: 100.0; Temp: 98.3; Arrival_TimeOfDay: 6am-12pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9015968277451051
# Pt_Prime_ICD10: R11.2
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: EMESIS; Triage_Acuity: 4.0; Gender: M; Race: SOMETHING ELSE; Ethnicity: Choose not to disclose; Pulse: 120.0; Resp: 40.0; SpO2: 100.0; Temp: 97.7; Arrival_TimeOfDay: 12pm-6pm; Age_Group: .5-1; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9011244601590851
# Pt_Prime_ICD10: B34.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: EMESIS; Triage_Acuity: 4.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 140.0; Resp: 23.0; SpO2: 98.0; Temp: 97.8; Arrival_TimeOfDay: 12pm-6pm; Age_Group: .5-1; Grouped_Arrival_Method: private transport; BP_Group: 0
# Similariry: 0.9011161913789418
# Pt_Prime_ICD10: H66.91
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: EMESIS; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 131.0; Resp: 18.0; SpO2: 97.0; Temp: 98.6; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.9010522086254069
# Pt_Prime_ICD10: B34.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan

# %% [markdown]
# #### Example 4

# %%
top_k = 5
patient_id = 10010
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
results = search_patients(df_patient_search, patient_info['combined'])

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: DENTAL PAIN; Triage_Acuity: 5.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 72.0; Resp: 18.0; SpO2: 100.0; Temp: 97.5; Arrival_TimeOfDay: Midnight-6am; Age_Group: 13-20; Grouped_Arrival_Method: private transport; BP_Group: high
# Pt_Prime_ICD10: nan
# Pt_Secondary_ICD10: R03.0
# Pt_Third_ICD10: nan
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: DENTAL PAIN; Triage_Acuity: 5.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 74.0; Resp: 16.0; SpO2: 99.0; Temp: 97.7; Arrival_TimeOfDay: Midnight-6am; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.9987675484025071
# Pt_Prime_ICD10: K02.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: DENTAL PAIN; Triage_Acuity: 5.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 52.0; Resp: 20.0; SpO2: 100.0; Temp: 98.0; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 13-20; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.9982069893182098
# Pt_Prime_ICD10: nan
# Pt_Secondary_ICD10: K02.9
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: DENTAL PAIN; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 79.0; Resp: 20.0; SpO2: 100.0; Temp: 98.1; Arrival_TimeOfDay: Midnight-6am; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.9971957581443291
# Pt_Prime_ICD10: K02.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: DENTAL PAIN; Triage_Acuity: 5.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 68.0; Resp: 18.0; SpO2: 99.0; Temp: 98.9; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9964115145715866
# Pt_Prime_ICD10: nan
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: DENTAL PAIN; Triage_Acuity: 5.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 60.0; Resp: 20.0; SpO2: 97.0; Temp: 97.1; Arrival_TimeOfDay: Midnight-6am; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: at_risk
# Similariry: 0.99640300101367
# Pt_Prime_ICD10: nan
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan

# %% [markdown]
# #### Example 5

# %%
top_k = 5
patient_id = 10110
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
results = search_patients(df_patient_search, patient_info['combined'])

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: MEDICATION REACTION; Triage_Acuity: 3.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 93.0; Resp: 17.0; SpO2: 100.0; Temp: 97.7; Arrival_TimeOfDay: 6am-12pm; Age_Group: 60-80; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Pt_Prime_ICD10: Z13.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: MEDICATION REACTION; Triage_Acuity: 3.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 109.0; Resp: 18.0; SpO2: 99.0; Temp: 99.2; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 20-40; Grouped_Arrival_Method: ambulance; BP_Group: at_risk
# Similariry: 0.9955260238216732
# Pt_Prime_ICD10: R06.02
# Pt_Secondary_ICD10: T40.425A
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: MEDICATION REACTION; Triage_Acuity: 3.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 75.0; Resp: 16.0; SpO2: 96.0; Temp: 97.9; Arrival_TimeOfDay: 6am-12pm; Age_Group: 80-100; Grouped_Arrival_Method: private transport; BP_Group: at_risk
# Similariry: 0.9922822625061494
# Pt_Prime_ICD10: S90.821A
# Pt_Secondary_ICD10: S90.822A
# Pt_Third_ICD10: L53.9
#
# Matched Patient 3: Complaint: MEDICATION REACTION; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 92.0; Resp: 18.0; SpO2: 96.0; Temp: 97.7; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: private transport; BP_Group: normal
# Similariry: 0.9920245027571918
# Pt_Prime_ICD10: R55
# Pt_Secondary_ICD10: R42
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: MEDICATION REACTION; Triage_Acuity: 3.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 89.0; Resp: 23.0; SpO2: 97.0; Temp: 98.0; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: high
# Similariry: 0.9919932710957508
# Pt_Prime_ICD10: R06.02
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: MEDICATION REACTION; Triage_Acuity: 3.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 102.0; Resp: 22.0; SpO2: 99.0; Temp: 98.2; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 20-40; Grouped_Arrival_Method: private transport; BP_Group: at_risk
# Similariry: 0.9911723234467487
# Pt_Prime_ICD10: R42
# Pt_Secondary_ICD10: R55
# Pt_Third_ICD10: R05.9

# %% [markdown]
# #### Example 6

# %%
top_k = 5
patient_id = 20000
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
results = search_patients(df_patient_search, patient_info['combined'])

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 76.0; Resp: 15.0; SpO2: 98.0; Temp: 99.3; Arrival_TimeOfDay: Midnight-6am; Age_Group: 60-80; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Pt_Prime_ICD10: R07.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: F; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 77.0; Resp: 14.0; SpO2: 100.0; Temp: 98.4; Arrival_TimeOfDay: Midnight-6am; Age_Group: 80-100; Grouped_Arrival_Method: ambulance; BP_Group: high
# Similariry: 0.9963186277495532
# Pt_Prime_ICD10: R07.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 105.0; Resp: 19.0; SpO2: 95.0; Temp: 97.6; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: at_risk
# Similariry: 0.9958320359293663
# Pt_Prime_ICD10: R07.89
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 102.0; Resp: 18.0; SpO2: 95.0; Temp: 98.3; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Similariry: 0.9954095171470183
# Pt_Prime_ICD10: R07.9
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 86.0; Resp: 40.0; SpO2: 97.0; Temp: 97.2; Arrival_TimeOfDay: 6am-12pm; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: high
# Similariry: 0.9949754700662676
# Pt_Prime_ICD10: F19.10
# Pt_Secondary_ICD10: F32.A
# Pt_Third_ICD10: R45.851
#
# Matched Patient 5: Complaint: CHEST PAIN; Triage_Acuity: 2.0; Gender: M; Race: WHITE OR CAUCASIAN; Ethnicity: Choose not to disclose; Pulse: 109.0; Resp: 20.0; SpO2: 92.0; Temp: 98.9; Arrival_TimeOfDay: 6am-12pm; Age_Group: 60-80; Grouped_Arrival_Method: ambulance; BP_Group: at_risk
# Similariry: 0.9949116351771553
# Pt_Prime_ICD10: J44.9
# Pt_Secondary_ICD10: R09.02
# Pt_Third_ICD10: F17.210

# %% [markdown]
# #### Example 7

# %%
top_k = 5
patient_id = 50000
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
results = search_patients(df_patient_search, patient_info['combined'])

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

print(f"\nTop {top_k} Matched Patients: \n")

for idx in range(0, top_k):
    
    matched_patient = results.iloc[idx]
    print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
    print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
    print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
    print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
    print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
    print()
# Out:
# Search Patient: Complaint: BACK PAIN; Triage_Acuity: 4.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 106.0; Resp: 17.0; SpO2: 97.0; Temp: 98.6; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Pt_Prime_ICD10: M54.50
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Top 5 Matched Patients:
#
# Matched Patient 1: Complaint: BACK PAIN; Triage_Acuity: 4.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 77.0; Resp: 16.0; SpO2: 100.0; Temp: 98.1; Arrival_TimeOfDay: 6am-12pm; Age_Group: 60-80; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Similariry: 0.997372208429384
# Pt_Prime_ICD10: N20.1
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 2: Complaint: BACK PAIN; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 83.0; Resp: 20.0; SpO2: 97.0; Temp: 97.9; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Similariry: 0.9962241617988238
# Pt_Prime_ICD10: N12
# Pt_Secondary_ICD10: M54.50
# Pt_Third_ICD10: nan
#
# Matched Patient 3: Complaint: BACK PAIN; Triage_Acuity: 4.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 70.0; Resp: 18.0; SpO2: 98.0; Temp: 97.0; Arrival_TimeOfDay: 12pm-6pm; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Similariry: 0.9961843760177908
# Pt_Prime_ICD10: S39.012A
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 4: Complaint: BACK PAIN; Triage_Acuity: 3.0; Gender: M; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 59.0; Resp: 16.0; SpO2: 100.0; Temp: 98.6; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 40-60; Grouped_Arrival_Method: ambulance; BP_Group: high
# Similariry: 0.9958145506337707
# Pt_Prime_ICD10: M54.50
# Pt_Secondary_ICD10: nan
# Pt_Third_ICD10: nan
#
# Matched Patient 5: Complaint: BACK PAIN; Triage_Acuity: 3.0; Gender: F; Race: UNKNOWN; Ethnicity: Choose not to disclose; Pulse: 148.0; Resp: 20.0; SpO2: 95.0; Temp: 97.9; Arrival_TimeOfDay: 6pm-Midnight; Age_Group: 80-100; Grouped_Arrival_Method: ambulance; BP_Group: normal
# Similariry: 0.9955852395913064
# Pt_Prime_ICD10: K56.7
# Pt_Secondary_ICD10: R11.10
# Pt_Third_ICD10: nan

# %% [markdown]
# ## GCS Vector Search

# %% [markdown]
# #### Save the embeddings in a JSON file

# %%
print("Data with Embeddings: ")
display(df_copy.head(2))

print("\nFilter df for vector search: ")
df_filter = df_copy[["PT_Visit_ID_Hashed", "embedding"]]
df_filter.columns = ["id", "embedding"]
display(df_filter.head(2))
# Out:
# Data with Embeddings:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 print("Data with Embeddings: ")
# ----> 2 display(df_copy.head(2))
#       4 print("\nFilter df for vector search: ")
#       5 df_filter = df_copy[["PT_Visit_ID_Hashed", "embedding"]]
#
# NameError: name 'df_copy' is not defined

# %%
# First, export the id and embedding columns from the DataFrame in JSONL format, and save it.

# save id and embedding as a json file
jsonl_string = df_filter.to_json(orient = 'records', lines = True)
with open('./data/deidentified/aiipem_deidentified_data_20231208.json', 'w') as f:
  f.write(jsonl_string)

# %%
# show the first few lines of the json file
! head -n 1 ./data/deidentified/aiipem_deidentified_data_20231208.json
# Out:
# {"id":"c1cf913b612ffce254b33e996aa49b0def330b033058a782cb0d7e5de368a121","embedding":[0.0095600504,0.0027575754,0.0064827814,-0.0455709435,-0.0068247002,0.0127672497,-0.0222931094,-0.0193115771,-0.0409755558,-0.0174925681,-0.0165625494,0.0169318207,0.0030943656,0.0215955935,-0.0008684738,0.0267107002,0.0278321933,-0.0047800252,0.0110850092,-0.0112354532,-0.0109687569,0.0457077101,-0.0223204624,0.018367881,-0.0188328903,0.0071461038,-0.0013121136,-0.0213767663,-0.0069067609,-0.0356689729,0.0105516156,-0.0051322021,-0.0142238243,-0.0099840304,-0.0220195744,0.0069204373,-0.0048757629,-0.0245908033,0.0111260395,-0.0002120965,0.0241257939,0.0031046232,-0.0009300192,0.0163437203,-0.0038363293,0.0028601512,0.0163026899,-0.0126441587,-0.0315659493,0.0285297092,0.0039594201,-0.0112354532,-0.0166582856,0.0034191885,0.0309915245,-0.0195851121,0.027462922,0.0200501215,-0.0254934691,0.0039628395,-0.0006868295,-0.018914951,-0.0118850991,-0.0056143072,-0.0368998833,-0.004448364,-0.0091292327,0.021855453,0.0127877649,0.0300615039,0.0085206171,0.000720594,0.006804185,0.0076247901,0.0292682536,0.0013796425,0.0010975595,-0.0058980999,0.0007445283,0.0060040951,0.0204193927,-0.0315112397,-0.0104558785,0.0184636172,0.0211989675,-0.0025045555,-0.0026447424,0.0158650335,-0.0294597279,-0.0022087956,-0.0029764036,0.0109003726,0.014880308,0.0155914994,0.0027883481,-0.0136015313,-0.0032670347,0.0166035797,0.0082060527,-0.0606153719,0.0089377584,0.0080145774,-0.0307179894,-0.0158923883,-0.0241941772,-0.0081718601,-0.0259174481,-0.0063186605,0.0159881245,-0.0063254987,-0.0075564063,0.0112559684,-0.0034721859,0.0032824208,-0.0051869089,-0.0152495801,0.0284202937,-0.0019968061,-0.0114611201,-0.0347115993,0.011563695,0.0288305972,0.0156598836,-0.0171096195,0.0295417886,-0.0028037345,-0.0012522778,-0.0177250728,0.0092181321,0.020337332,0.0029063101,0.0076658204,0.0195304044,0.010941403,-0.0152495801,0.0068007656,-0.0175746288,0.0113038374,-0.0196534954,-0.0059972564,-0.0015984706,0.0464462563,-0.0213630889,-0.0265192259,-0.0215408877,0.008896728,0.0330703892,0.0099156462,-0.0008338546,0.001483073,0.0186140612,-0.0052211005,0.0041611525,-0.0018497809,-0.0213494133,0.0098130712,-0.0009411316,0.0315659493,0.0147845708,-0.0089856274,-0.0222931094,0.0060827364,-0.0001786526,-0.015427378,0.0156325288,0.0135810161,-0.0038568445,-0.0115021495,-0.003757688,-0.0051492979,-0.0110234637,0.0282288194,0.0035730519,0.0084317187,0.0341098234,0.0236060768,0.0222110488,-0.0164394584,-0.0157419443,-0.0261225998,-0.0278048404,-0.0057613323,0.0390881635,0.0125962906,-0.0220742803,0.0087120924,0.0351766124,-0.0293776672,0.0135126328,-0.0177113954,0.0155231152,0.0364075191,0.0240300559,0.0043081776,-0.6394156218,-0.0402917154,-0.0029251156,-0.0057921051,-0.0018138795,0.0411396772,-0.0025045555,-0.0099293236,-0.0092386473,0.0150307519,-0.0130202696,0.027914254,0.0014523003,0.0027233835,-0.0184089113,-0.01739683,0.0095395362,0.0163437203,0.0145247122,-0.0132664507,-0.0083428202,0.0047048032,0.020063797,0.0139160967,0.0154547319,0.0107841203,0.0159607716,-0.0003532449,-0.0097652022,-0.0059596454,-0.0130202696,0.0201868881,-0.0001515128,0.0006714431,0.0461727194,-0.0191201009,-0.0243309457,0.0115431799,0.0151675204,0.0136904307,-0.0096968189,-0.0056655952,0.0225939974,-0.0321677253,-0.0326874405,0.0129108559,0.0081581837,-0.0058262972,-0.0094574755,-0.0060793171,0.021705009,0.016124893,-0.0187371522,0.0189696569,-0.0003051626,-0.0244950652,0.0338362902,0.0034636378,-0.0012078283,-0.0123706236,-0.011139716,0.032495968,-0.0091018798,-0.0366537012,-0.0080214161,0.0126168057,-0.0049202121,0.0243309457,0.0257670041,-0.0144836819,0.0090061426,0.0226213504,-0.0055937921,0.0247138944,0.0368725285,-0.0000483495,0.0182174351,-0.0031063326,-0.0225529671,0.0092044557,0.0127467345,0.0177934561,-0.0055937921,-0.0014309303,0.0185593553,0.0111670699,-0.0114953117,0.0026601285,-0.00442443,-0.0128698256,0.0123706236,0.0081376685,-0.005409156,-0.0042945007,0.0044791368,0.0228948854,-0.0045714551,-0.008766 ...

# %% [markdown]
# #### Copy the file to a new GCS bucket

# %%
BUCKET_NAME = "emopti_vector_search"
BUCKET_URI =  f"gs://{BUCKET_NAME}"
# ! gsutil -m cp ./data/deidentified/aiipem_deidentified_data_20231208.json {BUCKET_URI}

# %% [markdown]
# #### Create an Index
#
# The parameters for creating index
# - contents_delta_uri: The URI of Cloud Storage directory where you stored the embedding JSON files
# - dimensions: Dimension size of each embedding. In this case, it is 768 as we are using the embeddings from the Text Embeddings API.
# - approximate_neighbors_count: how many similar items we want to retrieve in typical cases
# - distance_measure_type: what metrics to measure distance/similarity between embeddings. In this case it's DOT_PRODUCT_DISTANCE

# %%
# init the aiplatform package
from google.cloud import aiplatform

PROJECT_ID = "healthlabs-genesis"
aiplatform.init(project=PROJECT_ID)

# LOCATION = "us-central-1"
# aiplatform.init(project=PROJECT_ID, location=LOCATION)

# %%
# create index
my_index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
  display_name = f"{BUCKET_NAME}-index",
  contents_delta_uri = BUCKET_URI,
  dimensions = 1536,
  approximate_neighbors_count = 20,
  distance_measure_type = "DOT_PRODUCT_DISTANCE",
)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/git/llms/venv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:79, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      78 try:
# ---> 79     return callable_(*args, **kwargs)
#      80 except grpc.RpcError as exc:
#
# File ~/git/llms/venv/lib/python3.10/site-packages/grpc/_channel.py:1160, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1154 (
#    1155     state,
#    1156     call,
#    1157 ) = self._blocking(
#    1158     request, timeout, metadata, credentials, wait_for_ready, compression
#    1159 )
# -> 1160 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/git/llms/venv/lib/python3.10/site-packages/grpc/_channel.py:1003, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1002 else:
# -> 1003     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Permission denied on resource project healthlabs-genesis."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.250.77.170:443 {created_time:"2024-01-02T10:40:03.312171623+05:30", grpc_status:7, grpc_message:"Permission denied on resource project healthlabs-genesis."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# Cell In[12], line 2
#       1 # create index
# ----> 2 my_index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
#       3   display_name = f"{BUCKET_NAME}-index",
#       4   contents_delta_uri = BUCKET_URI,
#       5   dimensions = 1536,
#       6   approximate_neighbors_count = 20,
#       7   distance_measure_type = "DOT_PRODUCT_DISTANCE",
#       8 )
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/cloud/aiplatform/matching_engine/matching_engine_index.py:527, in MatchingEngineIndex.create_tree_ah_index(cls, display_name, contents_delta_uri, dimensions, approximate_neighbors_count, leaf_node_embedding_count, leaf_nodes_to_search_percent, distance_measure_type, description, labels, project, location, credentials, request_metadata, sync, index_update_method, encryption_spec_key_name)
#     515 algorithm_config = matching_engine_index_config.TreeAhConfig(
#     516     leaf_node_embedding_count=leaf_node_embedding_count,
#     517     leaf_nodes_to_search_percent=leaf_nodes_to_search_percent,
#     518 )
#     520 config = matching_engine_index_config.MatchingEngineIndexConfig(
#     521     dimensions=dimensions,
#     522     algorithm_config=algorithm_config,
#     523     approximate_neighbors_count=approximate_neighbors_count,
#     524     distance_measure_type=distance_measure_type,
#     525 )
# --> 527 return cls._create(
#     528     display_name=display_name,
#     529     contents_delta_uri=contents_delta_uri,
#     530     config=config,
#     531     description=description,
#     532     labels=labels,
#     533     project=project,
#     534     location=location,
#     535     credentials=credentials,
#     536     request_metadata=request_metadata,
#     537     sync=sync,
#     538     index_update_method=index_update_method,
#     539     encryption_spec_key_name=encryption_spec_key_name,
#     540 )
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:817, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     815     if self:
#     816         VertexAiResourceNounWithFutureManager.wait(self)
# --> 817     return method(*args, **kwargs)
#     819 # callbacks to call within the Future (in same Thread)
#     820 internal_callbacks = []
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/cloud/aiplatform/matching_engine/matching_engine_index.py:213, in MatchingEngineIndex._create(cls, display_name, contents_delta_uri, config, description, labels, project, location, credentials, request_metadata, sync, index_update_method, encryption_spec_key_name)
#     209     gapic_index.labels = labels
#     211 api_client = cls._instantiate_client(location=location, credentials=credentials)
# --> 213 create_lro = api_client.create_index(
#     214     parent=initializer.global_config.common_location_path(
#     215         project=project, location=location
#     216     ),
#     217     index=gapic_index,
#     218     metadata=request_metadata,
#     219 )
#     221 _LOGGER.log_create_with_lro(cls, create_lro)
#     223 created_index = create_lro.result(timeout=None)
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/cloud/aiplatform_v1/services/index_service/client.py:592, in IndexServiceClient.create_index(self, request, parent, index, retry, timeout, metadata)
#     587 metadata = tuple(metadata) + (
#     588     gapic_v1.routing_header.to_grpc_metadata((("parent", request.parent),)),
#     589 )
#     591 # Send the request.
# --> 592 response = rpc(
#     593     request,
#     594     retry=retry,
#     595     timeout=timeout,
#     596     metadata=metadata,
#     597 )
#     599 # Wrap the response in an operation future.
#     600 response = gac_operation.from_gapic(
#     601     response,
#     602     self._transport.operations_client,
#     603     gca_index.Index,
#     604     metadata_type=index_service.CreateIndexOperationMetadata,
#     605 )
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/git/llms/venv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:81, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      79     return callable_(*args, **kwargs)
#      80 except grpc.RpcError as exc:
# ---> 81     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Permission denied on resource project healthlabs-genesis. [links {
#   description: "Google developers console"
#   url: "https://console.developers.google.com"
# }
# , reason: "CONSUMER_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "aiplatform.googleapis.com"
# }
# metadata {
#   key: "consumer"
#   value: "projects/healthlabs-genesis"
# }
# ]

# %% [markdown]
# #### Create Index Endpoint and deploy the Index

# %%
# create IndexEndpoint
my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
  display_name = f"{BUCKET_NAME}-index-endpoint",
  public_endpoint_enabled = True,
)

# %%
DEPLOYED_INDEX_ID = f"{BUCKET_NAME}_deployed"

# deploy the Index to the Index Endpoint
my_index_endpoint.deploy_index(
  index = my_index, deployed_index_id = DEPLOYED_INDEX_ID
)

# %% [markdown]
# #### Run Query

# %%
top_k = 5
patient_id = 10005
df_patient_search = df_copy.copy()

patient_info = df_for_embeddings.iloc[patient_id]
test_embeddings = [get_embedding(patient_info['combined'], model=embedding_model)]

print(f"\n{bold_s}Search Patient{bold_e}: {patient_info['combined']}")
print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {patient_info['Pt_Prime_ICD10']}")
print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {patient_info['Pt_Secondary_ICD10']}")
print(f"{bold_s}Pt_Third_ICD10{bold_e}: {patient_info['Pt_Third_ICD10']}")

# print(f"\nTop {top_k} Matched Patients: \n")

# for idx in range(0, top_k):
    
#     matched_patient = results.iloc[idx]
#     print(f"{bold_s}Matched Patient {idx+1}{bold_e}: {matched_patient['combined']}")
#     print(f"{bold_s}Similariry{bold_e}: {matched_patient['similarity']}")
#     print(f"{bold_s}Pt_Prime_ICD10{bold_e}: {matched_patient['Pt_Prime_ICD10']}")
#     print(f"{bold_s}Pt_Secondary_ICD10{bold_e}: {matched_patient['Pt_Secondary_ICD10']}")
#     print(f"{bold_s}Pt_Third_ICD10{bold_e}: {matched_patient['Pt_Third_ICD10']}")
#     print()

# %%
# Test query
response = my_index_endpoint.find_neighbors(
  deployed_index_id = DEPLOYED_INDEX_ID,
  queries = test_embeddings,
  num_neighbors = 20,
)

# show the result
import numpy as np
for idx, neighbor in enumerate(response[0]):
  id = np.int64(neighbor.id)
  similar = df.query("id == @id", engine = "python")
  print(f"{neighbor.distance:.4f} {similar.title.values[0]}")

# %% [markdown]
# #### Get an existing Index
#
# To get an Index object that already exists, replace the following [your-index-id] with the index ID and run the cell. You can check the ID on the Vector Search Console > INDEXES tab - https://console.cloud.google.com/vertex-ai/matching-engine/indexes

# %%
my_index_id = f"{BUCKET_NAME}-index" # @param {type:"string"}
my_index = aiplatform.MatchingEngineIndex(my_index_id)

# %% [markdown]
# #### Get an existing Index Endpoint
#
# To get an Index Endpoint object that already exists, replace the following [your-index-endpoint-id] with the Index Endpoint ID and run the cell. You can check the ID on the Vector Search Console > INDEX ENDPOINTS tab - https://console.cloud.google.com/vertex-ai/matching-engine/index-endpoints

# %%
my_index_endpoint_id = f"{BUCKET_NAME}_deployed" # @param {type:"string"}
my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint(my_index_endpoint_id)

# %% [markdown]
# #### IMPORTANT: Cleaning Up
# In case you are using your own Cloud project, not a temporary project on Qwiklab, please make sure to delete all the Indexes, Index Endpoints and Cloud Storage buckets after finishing this tutorial. Otherwise the remaining objects would incur unexpected costs.

# %%
# # wait for a confirmation
# input("Press Enter to delete Index Endpoint, Index and Cloud Storage bucket:")

# # delete Index Endpoint
# my_index_endpoint.undeploy_all()
# my_index_endpoint.delete(force = True)

# # delete Index
# my_index.delete()

# # delete Cloud Storage bucket
# ! gsutil rm -r {BUCKET_URI}

# %% [markdown]
# ## ToDo

# %% [markdown]
# #### Mike
# 1. to add code snippets to clean the vitals like if Pulse is More than 100 add text "Tachycardic"
# 2. 'Pt_Prime_ICD10', 'Pt_Secondary_ICD10',  'Pt_Third_ICD10' - text mapping
#
# #### Narayan
# 1. Move the Code to Worshop and Ping Mike - <b>Done</v>
# 1.2 Include 'Diastolic_BP' and 'Systolic_BP', "Arrival Method' (could be tried)
# 2. Store the embeddings to GCS
# 3. Create Google Vector search pipeline
# 4. Create two pipelines
#     4.1 To Create embedings and store in GCS
#     4.2 Code to search the nearest patient - to return 2 information, patient ids of top_k patients, (what information can we get from ANN search (how far the matched patients are from the current patient), cosine similarity or something else which tells how close the match are, embdeings as well if possible
#
# #### Omar/Florin
# 1. Create a frontend app steamlite app or any other
# 2. What Diagnostics was taken for the patients

# %% [markdown]
# #### Ideas:  Help Dr. Pickup and Not miss Rare info
#
# 5k with Heart attacks
# and only 10 with 'diasection'
